# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(1)
plt.plot([1,1])
plt.figure(2)
plt.plot([1,2])

#find exampe data online
#be inspired by some examples she used
# emotions I  feel in a day

# tired 4

# frusterated 1
# happy 6
# excitement 3
# content 4
#
#trains ive taken in a week
# M 2
# L 14
# J 3
# other trains 5

#veggies ive eaten in a week
# carrots 1
# mushrooms 1
#lettuce 2
# onions 4

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [50,40,70,80,20]
y2 = [80,20,20,50,60]
y3 = [70,20,60,40,60]
y4 = [80,20,20,50,60]

#plot takes a bunch of arguments 
# read documentation here: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
plt.plot(x,y,'g',label='Enfield', linewidth=5)
plt.plot(x,y2,'c',label='Honda',linewidth=5)
plt.plot(x,y3,'k',label='Yahama',linewidth=5)
plt.plot(x,y4,'y',label='KTM',linewidth=5)
plt.title('bike details in line plot')
plt.ylabel('Distance in kms')
plt.xlabel('Days')
# adds a legend 
plt.legend()

# %%
# bar (list of x and y)
# if you don't set something like the color, it will use the default color 
# in this case, it is blue 
# color can someone take letters, names, or hex, rgba 
import numpy as np
import matplotlib.pyplot as plt

plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],
label='Enfield',width=.5)
plt.bar([0.26,1.25,2.25,3.25,4.25],[80,20,20,50,60],
label='Honda', color='r',width=.5)
plt.bar([0.31,1.5,2.5,3.5,4.5],[70,20,60,40,60],
label='Yamaha', color='y',width=.5)
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],
label='KTM', color='g',width=.5)
plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Bikes details in BAR PLOTTING')
# Out:
# Text(0.5, 1.0, 'Bikes details in BAR PLOTTING')

# %%
#veggies ive eaten in a week
# carrots 1
# mushrooms 1
#lettuce 2
# onions 4
#banana 3

veggie_inventory = {
    'carrot': 3, 
    'mushroom': 1, 
    'Lettuce': 2, 
    'onion': 4, 
    'banana': 3, 
    }

plt.bar(range(len(veggie_inventory)), list(veggie_inventory.values()), align='center', color=['#236E96', '#15B2D3', '#FFD700', '#F3872F', '#FF598F'])
plt.xticks(range(len(veggie_inventory)), list(veggie_inventory.keys()), rotation = 45)
# Out:
# ([<matplotlib.axis.XTick at 0x1b34317aa00>,
#   <matplotlib.axis.XTick at 0x1b34317a9d0>,
#   <matplotlib.axis.XTick at 0x1b343172dc0>,
#   <matplotlib.axis.XTick at 0x1b3431a4b80>,
#   <matplotlib.axis.XTick at 0x1b3431b0310>],
#  [Text(0, 0, 'carrot'),
#   Text(1, 0, 'mushroom'),
#   Text(2, 0, 'Lettuce'),
#   Text(3, 0, 'onion'),
#   Text(4, 0, 'banana')])

# %%
# tired 4

# frusterated 1
# happy 6
# excitement 3
# content 4

# %%
#trains ive taken in a week
# M 2
# L 14
# J 3
# other trains 5


import matplotlib.pyplot as plt
days = [1,2,3,4,5]
M =[0,0,0,5,0]
L = [8,8,8,8,8]
J =[3,2,0,3,0,0]
Other = [0,4,0,0,0]
slices = [17,3,1,2]
activities = ['M','L','J','Other']
cols = ['c','g','y','b']
plt.pie(slices,
labels=activities,
colors=cols,
startangle=90,
shadow= True,
#To “explode” a pie chart means to make one of the wedges of the pie chart to stand out. 
explode=(0,0.1,0,0),
autopct='%1.1f%%') # to the nearest .1% float 
plt.title('Trains I took this week')
# Out:
# Text(0.5, 1.0, 'Trains I took this week')

# %%
#emotions I  feel in a day

# tired 4

# frusterated 1
# happy 6
# excitement 3
# content 4

# adding labels and titles 

# plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
plt.plot([1,2,3,3,5])
plt.title('# of times I feel tired in a day')
plt.xlabel('number of times')
plt.ylabel('hours spent on campus')
# Out:
# Text(0, 0.5, 'hours spent on campus')
